# %%
# https://www.hackerrank.com/challenges/between-two-sets/problem

#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'getTotalX' function below.
#
# The function is expected to return an INTEGER.
# The function accepts following parameters:
#  1. INTEGER_ARRAY a
#  2. INTEGER_ARRAY b
#

def getTotalX(a, b):
    # Write your code here
    max_a = max(a)
    min_b = min(b)
    factor = [integer for integer in range(max_a, min_b + 1) if integer % max_a == 0]
    result = []
    if len(a) == 1:
        for f in factor:
            for e2 in b:
                if e2 % f == 0 and f not in result:
                    result.append(f)
                elif e2 % f != 0 and f in result:
                    result.remove(f)
                    break
                elif e2 % f == 0 and f in result:
                    continue
                else:
                    break

        return (len(result))


    if n >= 1 and m <= 10:
        for f in factor:
            for e1 in a:
                if f % e1 == 0 and f not in result:
                    result.append(f)
                elif f % e1 != 0 and f in result:
                    result.remove(f)
                    break
                elif f % e1 == 0 and f in result:
                    continue
                else:
                    break
                    
            for e2 in b:
                for r in result:
                    if e2 % r == 0 and r in result:
                        continue
                    elif e2 % r != 0 and r in result:
                        result.remove(r)
                        
        del factor
        return len(result)

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    first_multiple_input = input().rstrip().split()

    n = int(first_multiple_input[0])

    m = int(first_multiple_input[1])

    arr = list(map(int, input().rstrip().split()))

    brr = list(map(int, input().rstrip().split()))

    total = getTotalX(arr, brr)

    fptr.write(str(total) + '\n')

    fptr.close()
